# %% [markdown]
# ### Installing Claude Desktop
# - Download and install Claude Desktop
# - complete the set up
#
# ### Analogy:
# - This claude desktop is MCP host and connected with different MCP servers such as Websearch, Weather, monday.com, canva, Notion, Gmail, Slack, etc., etc.
# 1. install claude desktop
# 2. open the chat, file, settings, developer, add a new mcp server in the notepad file then close claude deskto and open again to take changes effect
# 3. Ask question to Claude Desktop for referrencing the added MCP server (for ex: airbnb) and allow access to airbnb MCP server
# 3. go to smithery.ai for more MCP servers
