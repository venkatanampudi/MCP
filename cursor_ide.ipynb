# %% [markdown]
# ### Cursor IDE
# #### Download the cursor IDE from cursor.com and complete the tour of the product. Its like VS code but we can add existing MCP servers and create custom MCP servers as well.
